# %% [markdown]
# ## Using pretrained models
# - Keras Applications provided deep learning models with pre-trained weights
# - Documentation: https://keras.io/applications/

# %%
import numpy as np

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# %% [markdown]
# ### Load image
# - Images can be loaded using load_img function

# %%
# img src = 'https://gfp-2a3tnpzj.stackpathdns.com/wp-content/uploads/2016/07/Dachshund-600x600.jpg'
img = load_img('dog.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600 at 0x2B8AED553C8>

# %% [markdown]
# ### Import model
# - Currently, seven models are supported
#     - Xception
#     - VGG16
#     - VGG19
#     - ResNet50
#     - InceptionV3
#     - InceptionResNetV2
#     - MobileNet

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 2s 0us/step

# %%
img = load_img('dog.jpg', target_size = (224, 224))    # image size can be calibrated with target_size parameter
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x2B89F878348>

# %%
img = img_to_array(img)
print(img.shape)
# Out:
# (224, 224, 3)

# %%
img = np.expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 224, 224, 3)

# %%
## prediction wo preprocessing
pred_class = model.predict(img)
# print(pred_class)

# %%
# print only top 10 predicted classes
n = 10
top_n = decode_predictions(pred_class, top=n)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step

# %%
for c in top_n[0]:
    print(c)
# Out:
# ('n02099849', 'Chesapeake_Bay_retriever', 0.5004646)
# ('n02099712', 'Labrador_retriever', 0.19408423)
# ('n02088364', 'beagle', 0.055846117)
# ('n02105412', 'kelpie', 0.034197725)
# ('n02087394', 'Rhodesian_ridgeback', 0.02148086)
# ('n02090379', 'redbone', 0.019448025)
# ('n04409515', 'tennis_ball', 0.014889464)
# ('n02100236', 'German_short-haired_pointer', 0.013312437)
# ('n02107142', 'Doberman', 0.009854675)
# ('n02107908', 'Appenzeller', 0.008381209)

# %%
img = preprocess_input(img)    # preprocess image with preprocess_input function
print(img.shape)
# Out:
# (1, 224, 224, 3)

# %%
## prediction with preprocessing
pred_class = model.predict(img)
# print(pred_class)

# %%
n = 10
top_n = decode_predictions(pred_class, top=n)

# %%
for c in top_n[0]:
    print(c)
# Out:
# ('n02106550', 'Rottweiler', 0.7156204)
# ('n02107142', 'Doberman', 0.10712539)
# ('n02107312', 'miniature_pinscher', 0.051518817)
# ('n02107908', 'Appenzeller', 0.03773272)
# ('n02101006', 'Gordon_setter', 0.030471016)
# ('n02112706', 'Brabancon_griffon', 0.013199493)
# ('n02089078', 'black-and-tan_coonhound', 0.012116586)
# ('n02108000', 'EntleBucher', 0.0034771902)
# ('n02099712', 'Labrador_retriever', 0.002470969)
# ('n02093754', 'Border_terrier', 0.001997008)
